# %% [markdown]
# # SC/BEP First Analysis

# %%
import pathlib
import pandas as pd
import geopandas as gpd
#from fuzzymatcher import link_table, fuzzy_left_join
# %matplotlib inline
pd.set_option('display.max_rows', 300)

# %% [markdown]
# ## Load datasets

# %%
country = gpd.read_file(pathlib.Path("country.geojson").open().read())

# %%
df = pd.read_csv("missions.csv", sep=';', header=0, encoding='cp1250', parse_dates=['debut', 'fin'])
df.sample(5)
# Out:
#           debut        fin pays_origine ville_origine         pays  \
# 6125 2020-02-20 2020-02-20     Belgique     Bruxelles  Royaume-Uni
# 958  2013-06-14 2013-06-23          NaN           NaN       Russie
# 5990 2019-12-13 2019-12-17     Belgique     Bruxelles  Royaume-Uni
# 4402 2018-09-08 2018-09-20     Belgique     Bruxelles      Espagne
# 895  2013-02-13 2013-02-14          NaN           NaN   Angleterre
#
#                        ville                                         lieu  \
# 6125                 Londres                     Aga Khan University [GB]
# 958   Moscou-Iasnaďa Poliana                    Musée d'Etat Leon Tolstoď
# 5990                  London  Birkbeck College, University of London [GB]
# 4402                  Madrid        Bircham International University [ES]
# 895                  Londres                                          NaN
#
#      mode_deplacement acronyme  \
# 6125            train     DECS
# 958               NaN      L&L
# 5990            train     DECS
# 4402   voiture_diesel    PHILO
# 895               NaN    PHILO
#
#                                                 libelle     faculte
# 6125  Dean's Office - Solvay Brussels School of Econ...         SBS
# 958                   Département de Langues et Lettres         LTC
# 5990  Dean's Office - Solvay Brussels School of Econ...         SBS
# 4402  Département de Philosophie et de Sciences des ...  PHILOSCSOC
# 895   Département de Philosophie et de Sciences des ...  PHILOSCSOC

# %% [markdown]
# ## Data Cleansing
#
# ### Swap inverted timestamps

# %%
df['elapsed'] = (df['fin'] - df['debut']).dt.days
df.loc[df['elapsed']<0,'fin'] = df.loc[df['elapsed']<0,'debut'].values
df.loc[df['elapsed']<0,'debut'] = df.loc[df['elapsed']<0,'fin'].values
df['elapsed'] = (df['fin'] - df['debut']).dt.days

# %% [markdown]
# ### Normalize country names

# %%
def norm(x, fromkey, tokey):
    x[tokey] = x[fromkey].str.normalize('NFKD')\
                         .str.encode('ascii', errors='ignore').str.decode('utf-8')\
                         .str.strip().str.lower()

# %%
def unique(x, columns):
    keys = set()
    for k in columns:
        keys.update(x[k].unique())
    return keys

# %%
norm(df, 'pays_origine', 'from_country')
norm(df, 'pays', 'dest_country')

# %%
unique(df, ['from_country', 'dest_country'])
# Out:
# {'',
#  'abkhazie / georgie',
#  'afrique du sud',
#  'agentine et chile',
#  'algerie',
#  'allemagne',
#  'allemagne, austria',
#  'amsterdam',
#  'angelterre',
#  'angleterre',
#  'arabie saoudite',
#  'argentine',
#  'armenie',
#  'armenie georgie',
#  'australie',
#  'australie & nouvelle-zelande',
#  'austria',
#  'autriche',
#  'azerbaddjan',
#  'azerbaijan',
#  'b',
#  'bahrein',
#  'bamako',
#  'be',
#  'begique',
#  'belgien',
#  'belgique',
#  'belgique / france',
#  'belgium',
#  'benin',
#  'benin / niger',
#  'benin et niger',
#  'bielorussie',
#  'birmanie',
#  'blegium',
#  'bolivie',
#  'bosnie-herzegovine',
#  'bresil',
#  'bresil et argentine',
#  'britain',
#  'brussels',
#  'bruxelles',
#  'bulgaria',
#  'bulgarie',
#  'burkina faso',
#  'burundi',
#  'burundi, rd congo',
#  'burundi, rwanda',
#  'buruni, rdcongo, rwanda',
#  'cambodge',
#  'cameroun',
#  'canada',
#  'canada & usa',
#  'canada (quebec)',
#  'canada + usa',
#  'canada and usa',
#  'canada/etats unis',
#  'cap-vert',
#  'cardiff',
#  'catalogne',
#  'chiine',
#  'chili',
#  'chili (ile de paques)',
#  'china',
#  'chine',
#  'chine, japon, coree',
#  'chypre',
#  'colombie',
#  'colombie et bresil',
#  'colombie et perou',
#  'comores',
#  'comores et tchad',
#  'congo',
#  'congo (rdc)',
#  'congo rdc',
#  'coree du sud',
#  'costa rica',
#  "cote d'ivoire",
#  'crcte',
#  'crete',
#  'croatie',
#  'croatie puis france',
#  'cuba',
#  'cuba, colombie',
#  'cz / uk',
#  'czech republic',
#  'danemark',
#  'danemark + norvcge',
#  'danemark + sucde',
#  'danemark/groenland',
#  'danmark',
#  'denmark',
#  'dfid',
#  'dijon',
#  'djibouti',
#  'ecosse',
#  'ecosse (gb)',
#  'egypte',
#  'emirats arabes unis',
#  'england',
#  'equateur',
#  'esgagne',
#  'espage',
#  'espagne',
#  'espagne; autriche',
#  'estonie',
#  'etas-unis',
#  'etats unis',
#  'etats-unis',
#  'etats-unis / espagne',
#  'etats-unis / puerto rico',
#  "etats-unis d'amerique",
#  'etats-unis et canada',
#  'ethiopie',
#  'ethiopie et congo',
#  'federation de russie',
#  'finland',
#  'finlande',
#  'florenze',
#  'fr',
#  'frabce',
#  'franc',
#  'france',
#  'france et grcce (crete)',
#  'france et italie',
#  'france et russie',
#  'france, japon',
#  'france, puis suisse',
#  'france/maroc',
#  'francr',
#  'frane',
#  'franec',
#  'freiburg',
#  'gabon',
#  'gabon et tchad',
#  'gambie',
#  'gb',
#  'gd luxembourg',
#  'gd luxembourg et france',
#  'georgie',
#  'germany',
#  'gerogie',
#  'ghana',
#  'gra ce',
#  'grand bretagne',
#  'grand duche de luxembourg',
#  'grand-bretagne',
#  'grand-duche de luxembourg',
#  'grand-duche du luxembourg',
#  'grande bretagne',
#  'grande-bretagne',
#  'grcce',
#  'grcce&',
#  'grece',
#  'greece',
#  'guinee',
#  "guinee et cote d'ivoire",
#  'guinee et togo',
#  'guyane francaise',
#  'hadti',
#  'haiti',
#  'holland',
#  'hollande',
#  'honduras',
#  'hong-kong',
#  'hongrie',
#  'hongrie + lettonie',
#  'hongrie / autriche',
#  'hongrie et autriche',
#  'hungary',
#  'inde',
#  'indonesie',
#  'iran',
#  'ireland',
#  'irelande',
#  'irlande',
#  'islande',
#  'israel',
#  'it',
#  'italia',
#  'italie',
#  'italie (sicile)',
#  'italiea',
#  'italy',
#  'itlaie',
#  'jaipur',
#  'japan',
#  'japon',
#  'jordanie',
#  'jordanie / arabie saoudite',
#  'kazakhstan',
#  'kenya',
#  'koweit',
#  "l'angleterre",
#  "l'autriche",
#  "l'ex-republique yougoslave de macedoine",
#  'la hollande',
#  'la norvcge',
#  'laos',
#  'laos & vietnam',
#  'laos/vietnam',
#  'laos/vietnam/australie',
#  'latvia',
#  'lemans et paris',
#  'les pays-bas',
#  'lettonie',
#  'liban',
#  'lille',
#  'lithuania',
#  'lithuanie',
#  'lituanie',
#  'luxembourg',
#  'luxembourg, france',
#  'macao',
#  'macedoine',
#  'madagascar',
#  'malaisie',
#  'mali',
#  'malte',
#  'maroc',
#  'maryland, usa',
#  'mauritanie',
#  'mayotte',
#  'mexico',
#  'mexique',
#  'montenegro',
#  'namibie',
#  nan,
#  'netherlands',
#  'niger',
#  'northern ireland',
#  'norvcge',
#  'norvege',
#  'norway',
#  'nouvelle zelande',
#  'nouvelle-zelande',
#  'ouganda',
#  'padoue',
#  'panama',
#  'paris',
#  'pay-bas',
#  'pays bas',
#  'pays bas, france',
#  'pays-bas',
#  'perou',
#  'philippines',
#  'poland',
#  'polande',
#  'pologna',
#  'pologne',
#  'pologne et bulgarie',
#  'portugal',
#  'prague',
#  'puerto rico',
#  'qatar',
#  'quebec',
#  'r.f.a.',
#  'rd congo',
#  'rdc',
#  'rdc, rwanda, burundi',
#  're. tcheque',
#  'rep tcheque',
#  'rep. democratique du congo',
#  'rep. tchcque',
#  'republique centrafricaine',
#  'republique chcque',
#  'republique de moldova',
#  'republique democratique du congo',
#  'republique democratique du congo : afrique du sud ; republique du congo',
#  'republique democratique du congo/rwanda',
#  'republique democratique populaire lao',
#  'republique dominicaine',
#  'republique du benin',
#  'republique du congo',
#  'republique du congo &  zambie',
#  'republique tchcque',
#  'republique tchcque, puis royaume-uni',
#  'republque tchcque',
#  'rfa',
#  'romanie',
#  'roumanie',
#  'rouyaume uni',
#  'royaume uni',
#  'royaume unie',
#  'royaume unis',
#  'royaume unive',
#  'royaume- uni',
#  'royaume-uni',
#  'royaume-uni (ulster)',
#  'royaume-uni puis france',
#  'royaume-uni/ecosse',
#  'royaume-unis',
#  'rpumanie',
#  'russie',
#  'rwanda',
#  'rwanda et tanzanie',
#  'rwanda, rdc, burundi',
#  'rwanda-republique democratique du congo',
#  'saint-sicge (etat de la cite du vatican)',
#  'senegal',
#  'serbie',
#  'sicile',
#  'singapour',
#  'slovaquie',
#  'slovenie',
#  'soudan',
#  'spain',
#  'sri lanka',
#  'sucde',
#  'sucde et bolivie',
#  'suede',
#  'suisse',
#  'suisse et france',
#  'sweden',
#  'swiss',
#  'switzerland',
#  'syrie',
#  'tadwan',
#  'taiwan',
#  'taiwan r.o.c.',
#  'tanzanie',
#  'tanzanie et rwanda',
#  'tchad',
#  'tchequie',
#  'territoire palestinien occupe',
#  'thadlande',
#  'tokyo',
#  'tunisie',
#  'turku',
#  'turquie',
#  'u.s.a.',
#  'u.s.a. & australie',
#  'uk',
#  'uk (ecosse)',
#  'ukraine',
#  'united kindgdom',
#  'united kingdom',
#  'united states',
#  'united states (us)',
#  'united states of america',
#  'united-kingdom',
#  'uruguay',
#  'us',
#  'usa',
#  'vientam',
#  'viet nam',
#  'vietnam',
#  'vietnam & laos',
#  'vietnam/laos',
#  'vvvvvvvvvv',
#  'vvvvvvvvvvvv',
#  'zimbabwe'}

# %%
norm(df, 'ville_origine', 'from_city')
norm(df, 'ville', 'dest_city')

# %%
unique(df, ['from_city', 'dest_city'])
# Out:
# {nan,
#  'columbia, mo',
#  'paris, compicgne, lille',
#  'salerne',
#  'waterloo',
#  'bukarest',
#  'bonifacio',
#  'perpignan',
#  'lausanne',
#  'philadelphia et seattle',
#  'anvers',
#  'coimbra, lisbonne',
#  'athcnes + sitia',
#  'egligny (f-77126)',
#  'warwick',
#  'bangor, manchester',
#  'buenos aires',
#  'pierrefitte-sur-seine',
#  'dinant/namur',
#  'toulouse, perpignan, montpellier',
#  'dakar / ziguinchor',
#  'guadalajara',
#  'toulouse/montepellier',
#  'copenhague + malmo',
#  'itanos (crcte orientale)',
#  'delhi',
#  'san jose',
#  'issoire',
#  'palma de mallorca',
#  'puebla',
#  'rabat, fes, meknes',
#  'lille et paris',
#  'bucarest, targoviste, braila',
#  'reykjavik',
#  'abomey',
#  'washington',
#  'karlsruhe',
#  'turin',
#  'aleria',
#  'fribourg',
#  'tours et dijon',
#  'providence, ri; new york city, ny',
#  'leyde',
#  'napoli',
#  'grainau',
#  'poznan',
#  'h? chi minh',
#  'paris/st-die-des-vosges',
#  'denver, co',
#  'prais',
#  'regensburg',
#  'amsterdam',
#  'dzaoudi',
#  'conakry',
#  'la havane, bogota',
#  'nancy',
#  'palaikastro, sitias (crcte)',
#  'clermont-ferrand, la gacilly, iakoutsk',
#  'denver',
#  'mayotte',
#  'princeton, nj',
#  'hatay',
#  'paris (banlieue)',
#  'budapest',
#  'athenes',
#  'limoges',
#  'malaga, granada, sevilla',
#  'dublin galway - limerick',
#  'bale',
#  'kosice',
#  'ramallah, wadi fukin',
#  'nimes',
#  'tourtour',
#  'antalya',
#  'addis et lubumbashi',
#  'miami; gainesville',
#  'barcellone',
#  'toulouse',
#  'watermael-boistfort',
#  'bujumbura, bukavu, kigali',
#  'saint-romain (prcs de beaune)',
#  'leuven',
#  'cluj-napoca',
#  'londre-warwick',
#  'rimini',
#  'bibracte',
#  'rabat/ifrane',
#  'saint-jacques de compostelle',
#  'santander',
#  'paris & preuilly',
#  'barcelonne',
#  'calgary (alberta)',
#  'francfort',
#  'beauvechain',
#  'rosario',
#  'paris / lyon',
#  'valenciennes',
#  'paleikastro',
#  'singapour',
#  'aix provence',
#  'kandi, banikoara, djougou, parakou',
#  'grahamstown',
#  'kharkiv',
#  'amman / al-ula',
#  'cotonou',
#  'issy-les-moulineaux',
#  'tunis',
#  'ljubljana',
#  'kigali/goma',
#  'tampere',
#  'tongeren',
#  'lyon',
#  'tubingen',
#  'tokyo - kyoto',
#  'glenthorne',
#  'buenos aires et santiago',
#  'arles',
#  'pori/bjorneborg',
#  'gand',
#  'paris / nanterre',
#  'barcelona; vienne',
#  'urbino',
#  'accra',
#  'apamee/damas',
#  'mindelo (sao vicente)',
#  'osuna et madrid',
#  'reggio emilia',
#  'le chesnay',
#  'milton keynes',
#  'agrigente',
#  'poitou/charente/saintonge',
#  'epinal',
#  'malanville et karimama',
#  'issoire / paris',
#  'lima et bogota',
#  'palaikastro sitias, crcte',
#  'merchtem',
#  'saint-petersbourg',
#  'zagreb',
#  'rome, naples, viterbo',
#  'kampala',
#  'budapest / vienne',
#  'munchen',
#  'cadzand-bad',
#  'tallinn',
#  'boulogne-sur-mer',
#  'giessen',
#  'farciennes/aiseau-presles',
#  'logono',
#  'sussex',
#  'regina',
#  'santa barbara + los angeles',
#  'mainz',
#  'libreville et province',
#  'pisa',
#  'minneapolis',
#  'alicante et madrid',
#  'kastro, siphnos (cyclades)',
#  'volos',
#  'karratha',
#  'differentes villes',
#  'panama city',
#  'dubrovnik',
#  'avignon',
#  'amiens',
#  'tegucigapa et bajo aguan',
#  'boston; philadelphie',
#  'le monastier sur gazeille',
#  'olloy-sur-viroin',
#  'wolverhampton',
#  'provo',
#  'spire et environs',
#  'calais',
#  'seville',
#  'hanovre',
#  'rouen via caen',
#  'miami',
#  'soignies',
#  'ande',
#  'munich',
#  'lille / tourcoing',
#  'mannheim',
#  'lima, arequipa, cuzco',
#  'iasi',
#  'amsterdam et paris',
#  'taichung',
#  'paris et tours',
#  'compicgne',
#  'sarrebruck',
#  'new york & melbourne',
#  'roubaix',
#  'toulouse et montpellier',
#  'marburg',
#  'ulm, munich, vienna',
#  'marseille / aix en provence',
#  'al ula',
#  'manchester',
#  'nicosie',
#  'clermont',
#  'katowice et varsovie',
#  'mali',
#  'kao hsiung',
#  'jinghong',
#  'lucerne',
#  'frasne',
#  'bochum',
#  'dresde',
#  'alicante/el argar',
#  'tangers',
#  'lubumbashi',
#  'wellington',
#  'albacete',
#  'dubai',
#  'poznan - kalisz',
#  'le havre',
#  'shanghai',
#  'flaran (condom)',
#  'copenhagen',
#  'kirkwall',
#  'padova',
#  'cadriff',
#  'mindelo',
#  'mainz (mayence)',
#  'cosenza',
#  'bujumbura',
#  'dakar - thics',
#  'valencia, granada, alicante',
#  'christchurch',
#  'piran',
#  'coventry',
#  'farciennes',
#  'campina grande',
#  'durango',
#  'venezia',
#  'palma',
#  'berlin',
#  'manille',
#  'prague, puis canterbury',
#  'bucarest',
#  'salt lake city et newark',
#  'tokyo',
#  'roskilde',
#  'bangkok et hua hin',
#  'jonkoping',
#  'fukui',
#  'sienne',
#  'furnes',
#  'macao',
#  'paris, divers crete',
#  'nyc',
#  'saint jerome',
#  'dom-le-mesnil',
#  'boffres',
#  'paris / figeac',
#  'amman petra',
#  '22017 loveno di menaggio',
#  'madison, wisconsin',
#  'thessaloniki',
#  'vienna',
#  'luxembourg',
#  'nivelles',
#  'paris et vincennes',
#  'takayama',
#  'viterbe',
#  'venise',
#  'frakfurt & wulkow',
#  'chambery',
#  'vientiane/hanod/sydney',
#  'oslo',
#  'marbourg',
#  'sain-denis',
#  'belgium',
#  'medellin',
#  'weimar',
#  'louxor',
#  'tarse',
#  'lodz',
#  'bruges',
#  'wurzburg',
#  'bloomington, indiana',
#  'quebec',
#  'rome et perugia',
#  'leiden',
#  'new york et montreal',
#  'prato et cagliari',
#  'salamanca',
#  'alexandrie',
#  'madrid & alicante',
#  'ciudad real',
#  'freiburg',
#  'tartu',
#  'sao paulo, brasilia rio',
#  'kristiansand',
#  'st gallen',
#  'namur',
#  'murcia',
#  'paris - nanterre',
#  'bristol',
#  'paris/saint-denis',
#  'poitiers',
#  'gengenbach',
#  'mallanville / niamey',
#  'auxerres',
#  'departement de la meuse',
#  'sofia',
#  'antakya',
#  'quebec/toronto',
#  'saint)germain-en-laye',
#  'urbeis',
#  'reaading',
#  'prague / canterbury',
#  'new york/philadelphie/boston',
#  'cluj',
#  'palaiokastro',
#  'st.andrews; london',
#  'blois',
#  'ville',
#  'la paz',
#  'aubenas',
#  'bangui',
#  'boston (worcester) et new york',
#  'cork',
#  'italie',
#  'calgary',
#  'banff',
#  'philippeville et viroinval',
#  'luxembourg et nancy',
#  'bergame',
#  'natal',
#  'quezon city (diliman campus) & iloilo (visayas campus)',
#  'pekin, wuhan, shanghai',
#  'corum',
#  'le caire',
#  'nuremberg',
#  'madrid',
#  'herning',
#  'douala',
#  'lugano',
#  'kiel',
#  'cheikh abadah',
#  'new york & philadelphie',
#  'indianapolis',
#  'prades',
#  'reus',
#  'moscou, nijni-novgorod, saint-petersbourg',
#  'aosta',
#  'capetown',
#  'shangad',
#  'varsovie et katowice',
#  'cargcse',
#  'puente viesgo - santander',
#  'kinshasa kananga lodja',
#  'varsovie,poznan',
#  'boumerdes',
#  'treignes',
#  'durban',
#  'lahr',
#  'san francisco',
#  'genoa',
#  'barcelone et reus',
#  'huy',
#  'kigali et arusha',
#  'seattle',
#  'vilnius',
#  'bonifacio, corse',
#  'hanoi& vientiane',
#  'barcelona',
#  'braunschweig',
#  'abu dhabi',
#  'genova',
#  'braine-lalleud',
#  'opole',
#  'konstanz',
#  'franc waret',
#  'metz',
#  'delft',
#  'pamplona',
#  'londres/cambridge',
#  'lund',
#  'niamey',
#  'kisangani, wanie-rukula',
#  'ny',
#  'carleton',
#  'leicester',
#  'doha',
#  'essen',
#  'frankfurt',
#  'aix-la-chapelle',
#  'aiseau-presles',
#  'charleville mezicres',
#  'kalamaki',
#  'menton + nice',
#  'jerusalem, tel aviv',
#  'tarragona',
#  'bruxelles',
#  'forli',
#  'catania',
#  'londre',
#  'dembeni',
#  'londres puis paris',
#  'san juan',
#  'cairo',
#  'the hague',
#  'kigali, bukavu, bujumbura',
#  'cracovie et sofia',
#  'strasbourg, paris',
#  'montpeller',
#  'therouanne',
#  'hong kong, guangzhou',
#  'oxford, londres',
#  'bucharest',
#  'guayaquil',
#  'saint-etienne',
#  'chicago',
#  'montevideo',
#  'beaulieu-sur-mer (villa kerylos)',
#  'moscou et saint petersbourg',
#  'auxerre',
#  'oujda',
#  'zurich',
#  'bruxelles-zaventem-genappe',
#  'paris et egligny (preuilly)',
#  'kananga',
#  'pise - riomaggiore',
#  'monterrey',
#  'leon et madrid',
#  'bukavu/goma',
#  'malaga',
#  'hambourg',
#  'ciudad mexico',
#  'louvain',
#  'vientiane/hanod',
#  'cgligny - 77126',
#  'palerme',
#  'nouvelle orleans, louisianne',
#  'pau',
#  'naples et rome',
#  'colombo',
#  'moscou-yasnada poliana',
#  'washington et los angeles',
#  'ithaca',
#  'cayenne et autres',
#  'tokyo and otsu',
#  'bruxelles/zaventem',
#  'bresil',
#  'skopje',
#  'opole et katowice',
#  'mexico city',
#  'austin + provo',
#  'bordeaux et paris',
#  'tarsus',
#  'orleans',
#  'ixelles',
#  'grenoble',
#  'la sage',
#  'alghero',
#  'clermont-ferrand',
#  'onati',
#  'amman / wadi musa',
#  'tunis, hammamet',
#  'capri',
#  'treia',
#  'saint emilion',
#  'montreal, quebec',
#  'salaya',
#  'sao paulo, brasilia, rio de janeiro',
#  'nice/toulon',
#  'mont-saint-odile',
#  'aix-en-marseille',
#  'moscou tomsk',
#  'cape town/stellenbosch',
#  'pays-bas',
#  'ia?i',
#  'southampton',
#  'pekin,',
#  'mexico',
#  'vorselaar',
#  'carthage',
#  'paris et lyon',
#  'brisbane',
#  'bologne',
#  'rabat et fes',
#  'arlington, va',
#  'le mans',
#  'grenoble / paris',
#  'luxor et cairo',
#  'karlstad',
#  'rabat et marrakech',
#  'bruxellles',
#  'paris-nanterre',
#  'limerick',
#  'lucca',
#  'portsmouth',
#  'nymburk',
#  'marseille',
#  'gerzensee (bern)',
#  'bath',
#  'odessa',
#  'st-andrews',
#  'corsica',
#  'ulcinj',
#  'fontainebleau',
#  'tongres',
#  'valladolid',
#  'monasitr',
#  'johannesbourg',
#  'pise',
#  'meudon',
#  'nazca',
#  'toulouse/montpellier',
#  'saint-omer et therouanne',
#  'lublin',
#  'stockholm et la paz',
#  'izmir',
#  'wolfenbuttel',
#  'braga',
#  'nashville',
#  'malmo',
#  'shanghai, wuhan, dalian',
#  'hong kong',
#  'lviv',
#  'targoviste',
#  'windhoek',
#  'roma',
#  'buxelles',
#  'edmonton',
#  'damas, apamee',
#  'brasilia',
#  'dortmund',
#  'nicotera',
#  'moulins sur allier',
#  'dunkerque',
#  'lausanne et paris',
#  'bouake',
#  'forle',
#  'menaggio',
#  'tarkwa',
#  'carbondale',
#  'cardiff',
#  'bamberg',
#  'varsovie/cracovie',
#  'jinan',
#  'teheran',
#  'zagora',
#  'chateau-thierry',
#  'birmingham',
#  'nyc, philadelphia, boston',
#  'wadi mussa',
#  'champaign',
#  'paris/le chesnay',
#  'prignac-et-marcamps (gironde)',
#  'viennes',
#  'saint denis',
#  'san diego',
#  'leon',
#  "moroni et n'djamena",
#  'campina grande et sao paulo',
#  'orebro',
#  'palaikastro, sitias (cra te)',
#  'saint-malo',
#  'oran',
#  'victoria, british columbia',
#  'sils maria',
#  'meknes',
#  'bar-sur-aube',
#  'sintra',
#  'brussel',
#  'cartagena de indias',
#  'djibouti',
#  'stuttgart',
#  'uberladia et rio de janeiro',
#  'sao paulo',
#  'athens',
#  'vicenza',
#  'campomoro',
#  'worclaw',
#  'nantes',
#  'nevers',
#  'phoenix',
#  'ischia porto',
#  'wuhan',
#  'nancy et clermond-ferrand',
#  'new brunswick',
#  'montreal et quebec',
#  'oxford',
#  'johannesburg',
#  'kobe',
#  'yerevan',
#  'cracivie',
#  'mcze',
#  'lens',
#  'port au prince',
#  'charleroi',
#  'luxembourg-ville',
#  'newcastle',
#  'auckland & wellington',
#  'lima et autres',
#  'monteral',
#  'tyr',
#  'paris / pantin',
#  'st andrews',
#  'mons',
#  'mumbay',
#  'badajoz',
#  'tours et nevers',
#  'lewisburg',
#  'chieti',
#  'kilwa',
#  'paris (cdg)',
#  'le cap',
#  'dajabon',
#  'humbeek',
#  'bordeaux et uzeste',
#  'kinsasha ; johanesburg ; brazzaville',
#  'loughborough',
#  'pekin',
#  'palo alto',
#  'cadiz',
#  'toulouse + montpellier',
#  'palekastro crete',
#  'kananga (kasad)',
#  'ascona',
#  'hamburg',
#  'barcelone/lleida',
#  '/',
#  'la laguna (tenerife)',
#  'new york',
#  'porec puis paray-le-monial',
#  'nanjing',
#  'auch',
#  'lleida',
#  'warsaw, gdansk',
#  'tanger - fcs - casablanca',
#  'winterthur',
#  'quenast',
#  'university of copenhagen',
#  'neuchatel',
#  'masvingo',
#  'lille metropole',
#  'johannesburg & cape town',
#  'potsdam',
#  'marseille, valence, lyon',
#  'braubach',
#  'dragoon',
#  'liverpool/glasgow',
#  'thessalonique',
#  'tournai',
#  'brazzavile',
#  'tarse et ankara',
#  'kinshasa + inongo',
#  'wuhan, hubei',
#  'stoke-on-trent',
#  'brasov',
#  'cracow',
#  'lumumbashi',
#  'greifswald',
#  'binche',
#  'athcne',
#  'saint-dizier',
#  'phoenix, az',
#  'erkner',
#  'ankara',
#  'durham',
#  'munster',
#  'tournus et bourg-en-bresse',
#  'sao paulo, uberlandia, buenos aires',
#  'landau in der pfalz',
#  'bordeaux',
#  'marrakech (et rabat)',
#  'washington, chapel hill',
#  'seatte',
#  'quenvec',
#  'msila',
#  'alcala de henares',
#  'kassel',
#  'le caire / louxor',
#  'marrakech',
#  'naples/procida',
#  'ho chi minh city',
#  'cambridge et londres',
#  'karimama, malanville (benin) ; tillaberi, dosso (niger)',
#  'tooulouse/montpellier',
#  'athcnes',
#  'gent',
#  'carlisle',
#  'paroikia',
#  'ramillies',
#  'athens, georgia & washington, dc',
#  'chicago et san francisco',
#  'haifa et jerusalem',
#  'los angeles / barcelone',
#  'brest',
#  'atlanta',
#  'augsburg',
#  'washington, dc and los angeles',
#  'saint petersbourg',
#  'agadir',
#  'moscow, idaho',
#  'tegucigalpa et bajo aguan',
#  'auvelais',
#  'gerone',
#  'toulouse, montpellier',
#  'marrakech et rabat',
#  'kyoto & tokyo',
#  'glasgow',
#  'caen',
#  'bielefeld',
#  'soignies - mons',
#  'pretoria',
#  'montreal + ottawa',
#  'mouzon',
#  'bamako',
#  'montpellier/perpignan/toulouse',
#  'catane',
#  'strasbourg colmar',
#  'landau',
#  'faro',
#  'alba di canazei',
#  'venice',
#  'paris + rennes',
#  'lima - cuzco',
#  'dnipro',
#  'pordenone',
#  'madrid & leon',
#  'miyazaki',
#  'barcelone',
#  'dublin, cork, limerick, galway',
#  'kuala lumpur',
#  'wroc?aw',
#  'tlemcen',
#  'duisburg',
#  'santiago de compostela',
#  'toulouse/montpellier/perpigan',
#  'madison',
#  'kigali, butare',
#  'cagliari',
#  'antwerp',
#  'johannesbrug',
#  'washington d.c.',
#  'valence',
#  'new york, princeton ithaka',
#  'motreal',
#  'tel aviv',
#  'amersfoort',
#  'alicante',
#  'gdansk',
#  'la coruna',
#  'narbonne',
#  'amman, tafileh',
#  'paris/tours',
#  'cotonou, ouidah, abomey',
#  'lisbonne',
#  'los angeles, phoenix, boston, new york',
#  'girona',
#  'columbia (south-carolina)',
#  'utrecht',
#  'tokyo, kyoto, osaka',
#  'montreal edmonton',
#  'vichy et marseille',
#  'ciudad de mexico',
#  'chisinau',
#  'verone et florence',
#  'libreville et ndjamena',
#  'beijing',
#  'montreal - quebec - halifax',
#  'vientiane',
#  'macerata',
#  'edimbourg',
#  'salzburg',
#  'aachen (aix-la-chapelle)',
#  'scte',
#  'espagne',
#  'new orleans',
#  'cadix',
#  'szeged',
#  'etterbeek',
#  'mexico city df',
#  'vientiane - luang prabang',
#  'verone',
#  'madrid & salamanca',
#  'strabsourg',
#  'bujumbura, kigali',
#  'las palmas',
#  'avignon et marseille',
#  'paris et strasbourg',
#  'briuxelles',
#  'brno',
#  'stockholm',
#  'st-louis, missouri',
#  'moscou-iasnada poliana',
#  'libreville',
#  'tours',
#  'kaolack',
#  'arras - dainville (62000)',
#  'stadtoldendorf',
#  'palaikastro',
#  'bogota et al.',
#  'adelaide, brisbane, sydney',
#  'dijon',
#  'esch-sur-alzette',
#  'puente viesgo',
#  'toronto',
#  'hanoi',
#  'lima',
#  'itanos',
#  'gatineau',
#  'kolwezi',
#  'conakry et abiddan',
#  'minsk',
#  'montreal-quebec',
#  'la valette',
#  'palo alto, ca',
#  'tijuana et ciudad de mexico',
#  'marseille + lille',
#  'chongqing',
#  'mulhouse',
#  'paris (boulevard du lycee, vanves)',
#  'addis ababa',
#  'le croisic',
#  'troie',
#  'klagenfurt',
#  'dijon, beaune, grenoble etc',
#  'pozna?',
#  'bidart (bayonne/biarritz)',
#  'galway',
#  'kaunas',
#  'hiroshima',
#  'cusco',
#  'ghent',
#  'torino',
#  'basel',
#  'paris/marrakech',
#  'cambridge',
#  'licge',
#  "moulin d'ande",
#  'hasselt',
#  'bet medhane alem',
#  'alicante & madrid',
#  'palaikastro sitias',
#  'france',
#  'malanville / gaya',
#  'besancon',
#  'shenzhen',
#  'paris et lille',
#  'kigali',
#  'biarritz',
#  'bastia',
#  'shanghai - wuhan - dalian',
#  'boston',
#  'sapporo',
#  'eskisehir',
#  'le caire et louqsor',
#  'saint-etienne-de-badgorry',
#  'nairobi',
#  'lyon et paris',
#  'antwerpen',
#  'wadi musa',
#  'thics',
#  'matera',
#  'pontresina',
#  'kigali, butare, goma, bukavu, bujumbura',
#  'petra',
#  'pittsburgh',
#  'thuin',
#  'glux-en-glenne',
#  'lissabon',
#  'hochi min',
#  'florianopolis',
#  'guildford, surrey',
#  'washington, d.c.; new york',
#  'nogent sur marne',
#  'stanford',
#  'budapest + riga',
#  'sanok',
#  'uberlandia, diamantina, ouro preto, brasilia, rio',
#  'trondheim',
#  'arras',
#  'rouen',
#  'lisbon',
#  'bogota',
#  'bilbao',
#  'castellon',
#  'saigon',
#  'leeds et oxford',
#  'prato',
#  'jyvaskyla',
#  'royaume-uni',
#  'amay - la paix-dieu awap',
#  'meknes et rabat',
#  'aix-en-provence',
#  'berne',
#  'mont-beuvray',
#  'spoleto',
#  'dakar',
#  'bruxelle',
#  'sydney',
#  'koweit city',
#  'graz',
#  'egligny',
#  'sint-pieters-leeuw',
#  'orlando',
#  'auckland',
#  'leysin',
#  'ratisbonne',
#  'seoul',
#  'lausanne, gencve et lyon',
#  'porto alegre',
#  'wuppertal',
#  'bremen',
#  'katowice',
#  'bran',
#  'carcassonne',
#  'cluj napoca',
#  'kisangani',
#  'viroinval',
#  'riyadh - al-ula - madain saleh',
#  'augsbourg',
#  'vancouver and boston',
#  'natale',
#  'amsterdam-utrecht',
#  'montpellier',
#  'goma/kigali',
#  'belfast',
#  'riod e janeiro, belo horizonte, salvador de bahia, recife',
#  'tokyo, kyoto et nagoya',
#  'le caire et louxor',
#  'saint-emilion',
#  'cape town',
#  'beaune et paris',
#  'modena',
#  'nouvelle orleans',
#  'washington d.c. et new york',
#  'saint-germain-en-laye',
#  'brussels',
#  'riga',
#  'bogota & cartagena',
#  'cambridge, ma',
#  '77126 egligny',
#  'siem rap (angkor)',
#  'istanbul',
#  'gotha/erfurt',
#  'longueil-sainte-marie',
#  'lima/pachacamac',
#  'lannion',
#  'cuzco',
#  'jerusalem',
#  'zhuhai (hong kong)',
#  'tourcoing',
#  'leipzig, magdebourg',
#  'baton rouge',
#  'inde',
#  'pierrefitte sur seine',
#  'bertinoro',
#  'paris / grenoble',
#  'la rochelle',
#  'dakar et saint-louis',
#  'strasbourg - colmar',
#  'valencia',
#  'luxembourg / campus belval',
#  'lille',
#  'roux-miroir',
#  'columbia',
#  'louvain-la-neuve',
#  'gembloux',
#  'szklarska por?ba',
#  'lecce',
#  'itanos, paleikastro, crcte',
#  'arusha et kigali',
#  'constantine',
#  'damas - apamee',
#  'bonn',
#  'taipei',
#  'berlin et leipzig',
#  'geneve et lausanne',
#  'duesseldorf',
#  'cologne',
#  'alba fucens',
#  'deir ez zor',
#  'egligny (77136) abbaye cistercienne de preuilly',
#  'cremona',
#  'sydney & wellington',
#  'palaikastro (crcte)',
#  'port au prince, arcahaie',
#  'noto',
#  'la londe les maures',
#  'hambourg et dresden',
#  'bethune',
#  'reims',
#  'amman - petra',
#  'douai',
#  'milan',
#  'belluno, ferrare, modene, parme',
#  'rome et viterbo',
#  'roscommon',
#  'luxeuil',
#  'copenhaguen/narsarsuaq et al.',
#  'ottawa et montreal',
#  'aalborg + kristiansand',
#  'toulon',
#  'toulouse/perpignan/montpellier',
#  ...}

# %%
#pd.DataFrame(list(df['origin'].unique()) + list(df['origin'].unique())).drop_duplicates().dropna().to_csv("origin.csv", index=False)

# %%
ctrans = pd.read_csv("country_trans.csv", keep_default_na=False)
ctrans['city'] = ctrans['city'].fillna(0).astype(bool)
ctrans.sample(5)
# Out:
#            original ISO2   city
# 40          senegal   SN  False
# 2             maroc   MA  False
# 13       angleterre   GB  False
# 11  grande-bretagne   GB  False
# 30          blegium   BE  False

# %%
df = df.merge(ctrans, left_on='origin', right_on='original', how='left')
df = df.drop(['origin', 'original'], axis=1).rename(columns={'ISO2': 'country_from'})
df['country_from'] = df['country_from'].fillna('BE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-dc08200eff4b> in <module>
# ----> 1 df = df.merge(ctrans, left_on='origin', right_on='original', how='left')
#       2 df = df.drop(['origin', 'original'], axis=1).rename(columns={'ISO2': 'country_from'})
#       3 df['country_from'] = df['country_from'].fillna('BE')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'origin'

# %%
df = df.merge(ctrans, left_on='dest', right_on='original', how='left')
df = df.drop(['dest', 'original'], axis=1).rename(columns={'ISO2': 'country_to'})

# %%
df

# %%
df.groupby('faculte')['acronyme'].count().plot(kind='bar')

# %%
df.groupby('acronyme')['acronyme'].count().plot(kind='bar')

# %%
df.groupby('elapsed')['acronyme'].count().plot(kind='hist', bins=30)
