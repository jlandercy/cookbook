# %% [markdown]
# # SC/BEP First Analysis

# %%
import pathlib
import pandas as pd
import geopandas as gpd
import geocoder
#from fuzzymatcher import link_table, fuzzy_left_join
# %matplotlib inline
pd.set_option('display.max_rows', 300)

# %% [markdown]
# ## Load datasets

# %%
country = gpd.read_file(pathlib.Path("country.geojson").open().read())

# %%
df = pd.read_csv("missions.csv", sep=';', header=0, encoding='cp1250', parse_dates=['debut', 'fin'])
df = df.reset_index()
df.sample(5)
# Out:
#       index      debut        fin pays_origine ville_origine      pays  \
# 2852   2852 2017-06-01 2017-08-31          NaN           NaN    Canada
# 4861   4861 2019-01-23 2019-01-25     Belgique     Bruxelles   Espagne
# 4005   4005 2018-06-04 2018-07-13     Belgique     Bruxelles  Belgique
# 2206   2206 2016-04-27 2016-04-27          NaN           NaN  Belgique
# 5744   5744 2019-09-20 2019-09-20     Belgique     Bruxelles  Pays-Bas
#
#           ville                            lieu       mode_deplacement  \
# 2852  vancouver  University of British Columbia                    NaN
# 4861  Barcelone   Universitat Pompeu Fabra [ES]  avion_courte_distance
# 4005      Thuin            Chantier école (ULB)                    NaN
# 2206       Mons                             NaN                    NaN
# 5744  Amsterdam    Vrije Universiteit Amsterdam                  train
#
#      acronyme                                            libelle     faculte
# 2852    ScPOL                 Département de Sciences Politiques  PHILOSCSOC
# 4861    ScSOC  Département de Sciences Sociales et des scienc...  PHILOSCSOC
# 4005      HAA        Département d'Histoire, arts et archéologie  PHILOSCSOC
# 2206      HAA        Département d'Histoire, arts et archéologie  PHILOSCSOC
# 5744    ScSOC  Département de Sciences Sociales et des scienc...  PHILOSCSOC

# %% [markdown]
# ## Data Cleansing
#
# ### Swap inverted timestamps

# %%
df['elapsed'] = (df['fin'] - df['debut']).dt.days
df.loc[df['elapsed']<0,'fin'] = df.loc[df['elapsed']<0,'debut'].values
df.loc[df['elapsed']<0,'debut'] = df.loc[df['elapsed']<0,'fin'].values
df['elapsed'] = (df['fin'] - df['debut']).dt.days

# %% [markdown]
# ### Normalize country names

# %%
def norm(x, fromkey, tokey):
    x[tokey] = x[fromkey].str.normalize('NFKD')\
                         .str.encode('ascii', errors='ignore').str.decode('utf-8')\
                         .str.strip().str.lower()

# %%
def unique(x, columns):
    keys = set()
    for k in columns:
        keys.update(x[k].dropna().unique())
    return keys

# %%
norm(df, 'pays_origine', 'from_country')
norm(df, 'pays', 'dest_country')

# %%
norm(df, 'ville_origine', 'from_city')
norm(df, 'ville', 'dest_city')

# %%
s = unique(df, ['from_city', 'dest_city'])

# %%
#df['from_city'] = df['from_city'].str.replace(r"\((.*?)\)","").str.split(r'/|,|\&| et | puis |\+|;')
df['dest_city'] = df['dest_city'].str.replace(r"\((.*?)\)","").str.split(r'/|,|\&| et | puis |\+|;')
df = df.explode('dest_city')

# %%
df
# Out:
#       index      debut        fin pays_origine ville_origine             pays  \
# 0         0 2010-05-28 2010-06-01          NaN           NaN  Grande Bretagne
# 0         0 2010-05-28 2010-06-01          NaN           NaN  Grande Bretagne
# 1         1 2010-06-22 2010-07-08          NaN           NaN      Royaume-Uni
# 2         2 2010-06-22 2010-07-08          NaN           NaN      Royaume-Uni
# 3         3 2010-07-12 2010-07-17          NaN           NaN      Royaume-Uni
# ...     ...        ...        ...          ...           ...              ...
# 6126   6126 2020-02-23 2020-02-28     Belgique     Bruxelles           France
# 6127   6127 2020-02-16 2020-02-18     Belgique     Bruxelles           France
# 6128   6128 2020-03-02 2020-03-03     Pays-Bas     Amsterdam           France
# 6129   6129 2020-01-28 2020-02-06     Belgique     Bruxelles       États-Unis
# 6129   6129 2020-01-28 2020-02-06     Belgique     Bruxelles       États-Unis
#
#                                ville  \
# 0                     Londres/Oxford
# 0                     Londres/Oxford
# 1                            Londres
# 2                            Londres
# 3                            Londres
# ...                              ...
# 6126  Toulouse/Perpignan/Montpellier
# 6127                          Pessac
# 6128                           Paris
# 6129         Washington, Chapel Hill
# 6129         Washington, Chapel Hill
#
#                                                    lieu  \
# 0                 Oxford University — All Souls College
# 0                 Oxford University — All Souls College
# 1     Archives du Royal Opera House Covent GardenArc...
# 2     Archives du Royal Opera House Covent GardenArc...
# 3     Archives du Royal Opera House Covent GardenArc...
# ...                                                 ...
# 6126                                 AgroParisTech [FR]
# 6127                   Université de Bordeaux-Montaigne
# 6128                                               OCDE
# 6129                  Abilene Christian University [US]
# 6129                  Abilene Christian University [US]
#
#              mode_deplacement acronyme  \
# 0                         NaN     DECA
# 0                         NaN     DECA
# 1                         NaN      SIC
# 2                         NaN      SIC
# 3                         NaN      SIC
# ...                       ...      ...
# 6126                    train     DECS
# 6127                    train      L&L
# 6128                    train     DECS
# 6129  avion_long_courrier_eco      L&L
# 6129  avion_long_courrier_eco      L&L
#
#                                                 libelle faculte  elapsed  \
# 0     Décanat de la Faculté de Lettres, Traduction e...     LTC        4
# 0     Décanat de la Faculté de Lettres, Traduction e...     LTC        4
# 1     Département des Sciences de l'information et d...     LTC       16
# 2     Département des Sciences de l'information et d...     LTC       16
# 3     Département des Sciences de l'information et d...     LTC        5
# ...                                                 ...     ...      ...
# 6126  Dean's Office - Solvay Brussels School of Econ...     SBS        5
# 6127                  Département de Langues et Lettres     LTC        2
# 6128  Dean's Office - Solvay Brussels School of Econ...     SBS        1
# 6129                  Département de Langues et Lettres     LTC        9
# 6129                  Département de Langues et Lettres     LTC        9
#
#      from_country     dest_country  from_city     dest_city
# 0             NaN  grande bretagne        NaN       londres
# 0             NaN  grande bretagne        NaN        oxford
# 1             NaN      royaume-uni        NaN       londres
# 2             NaN      royaume-uni        NaN       londres
# 3             NaN      royaume-uni        NaN       londres
# ...           ...              ...        ...           ...
# 6126     belgique           france  bruxelles   montpellier
# 6127     belgique           france  bruxelles        pessac
# 6128     pays-bas           france  amsterdam         paris
# 6129     belgique       etats-unis  bruxelles    washington
# 6129     belgique       etats-unis  bruxelles   chapel hill
#
# [6628 rows x 17 columns]

# %%
import time
def geocode(x):
    res = geocoder.osm(x).json
    time.sleep(1)
    return {k: (res or {}).get(k) for k in ['country_code', 'city', 'lat', 'lng', 'accuracy', 'confidence']}

# %%
city = pd.DataFrame(list(df['from_city'].dropna().unique()) + list(df['dest_city'].unique()), columns=['city'])
city
# Out:
#                 city
# 0          bruxelles
# 1          charleroi
# 2              paris
# 3         casablanca
# 4            reading
# ...              ...
# 1451      montpellie
# 1452  tokyo and otsu
# 1453         athenes
# 1454          pessac
# 1455     chapel hill
#
# [1456 rows x 1 columns]

# %%
citygc = city.loc[:10,'city'].apply(geocode).apply(pd.Series)
citygc
# Out:
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=bruxelles&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=charleroi&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=paris&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=casablanca&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=reading&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=londres&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=licge&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=lille&format=jsonv2&addressdetails=1&limit=1
# Status code 429 from https://nominatim.openstreetmap.org/search: ERROR - 429 Client Error: Too Many Requests for url: https://nominatim.openstreetmap.org/search?q=bruxelles%2Fzaventem&format=jsonv2&addressdetails=1&limit=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-b4d7706d59ff> in <module>
# ----> 1 citygc = city.loc[:10,'city'].apply(geocode).apply(pd.Series)
#       2 citygc
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-12-c796ba2a441e> in geocode(x)
#       2 def geocode(x):
#       3     res = geocoder.osm(x).json
# ----> 4     time.sleep(1)
#       5     return {k: (res or {}).get(k) for k in ['country_code', 'city', 'lat', 'lng', 'accuracy', 'confidence']}
#
# KeyboardInterrupt:

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="Mission")
location = geolocator.geocode("brussels")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# GeocoderQuotaExceeded                     Traceback (most recent call last)
# <ipython-input-15-41646269c70c> in <module>
#       1 from geopy.geocoders import Nominatim
#       2 geolocator = Nominatim(user_agent="Mission")
# ----> 3 location = geolocator.geocode("brussels")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\geopy\geocoders\osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     404
#     405         return self._parse_json(
# --> 406             self._call_geocoder(url, timeout=timeout), exactly_one
#     407         )
#     408
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     371                                 exc_info=False)
#     372                 try:
# --> 373                     raise ERROR_CODE_MAP[code](message)
#     374                 except KeyError:
#     375                     raise GeocoderServiceError(message)
#
# GeocoderQuotaExceeded: HTTP Error 429: Too Many Requests

# %% [markdown]
# x = df.loc[:20,:]
# y = x['dest_city'].apply(geocode).apply(pd.Series)

# %% [markdown]
# pd.concat([x,y], axis=1)
