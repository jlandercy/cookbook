# %% [markdown]
# # SC/BEP First Analysis

# %%
import sys
import time
import pathlib
import pandas as pd
import geopandas as gpd
import geocoder
from geopy.distance import geodesic
#from fuzzymatcher import link_table, fuzzy_left_join
# %matplotlib inline
pd.set_option('display.max_rows', 300)

# %% [markdown]
# ## Load datasets

# %%
country = gpd.read_file(pathlib.Path("country.geojson").open().read())

# %%
df = pd.read_csv("missions.csv", sep=';', header=0, encoding='cp1250', parse_dates=['debut', 'fin'])
df = df.reset_index().rename(columns={'index': 'mission_id'})
df.sample(5)
# Out:
#       mission_id      debut        fin pays_origine ville_origine  \
# 3124        3124 2017-06-06 2017-07-03          NaN           NaN
# 1108        1108 2013-11-11 2013-11-14          NaN           NaN
# 4679        4679 2018-11-23 2018-11-23     Belgique     Bruxelles
# 286          286 2011-04-29 2011-05-28          NaN           NaN
# 5801        5801 2019-10-30 2019-11-05      Begique     Bruxelles
#
#              pays               ville  \
# 3124        Maroc  Marrakech et Rabat
# 1108        Chine               Pékin
# 4679  Royaume-Uni              Oxford
# 286         Syrie                 NaN
# 5801        Maroc              Zagora
#
#                                          lieu       mode_deplacement acronyme  \
# 3124     Centre Jacques Berque (CNRS - Rabat)                    NaN    ScSOC
# 1108        Communication University of China                    NaN     DECA
# 4679                University of Oxford [GB]                  train     DECB
# 286                                       NaN                    NaN      HAA
# 5801  Structure : festival culturel Taragalte  avion_courte_distance      HAA
#
#                                                 libelle     faculte
# 3124  Département de Sciences Sociales et des scienc...  PHILOSCSOC
# 1108  Décanat de la Faculté de Lettres, Traduction e...         LTC
# 4679  Décanat de la Faculté de Philosophie et Scienc...  PHILOSCSOC
# 286         Département d'Histoire, arts et archéologie  PHILOSCSOC
# 5801        Département d'Histoire, arts et archéologie  PHILOSCSOC

# %% [markdown]
# ## Data Cleansing
#
# ### Swap inverted timestamps

# %%
df['elapsed'] = (df['fin'] - df['debut']).dt.days
df.loc[df['elapsed']<0,'fin'] = df.loc[df['elapsed']<0,'debut'].values
df.loc[df['elapsed']<0,'debut'] = df.loc[df['elapsed']<0,'fin'].values
df['elapsed'] = (df['fin'] - df['debut']).dt.days

# %% [markdown]
# ### Normalize country names

# %%
def norm(x, fromkey, tokey):
    x[tokey] = x[fromkey].str.normalize('NFKD')\
                         .str.encode('ascii', errors='ignore').str.decode('utf-8')\
                         .str.strip().str.lower()

# %%
def unique(x, columns):
    keys = set()
    for k in columns:
        keys.update(x[k].dropna().unique())
    return keys

# %%
norm(df, 'pays_origine', 'from_country')
norm(df, 'pays', 'dest_country')

# %%
norm(df, 'ville_origine', 'from_city')
norm(df, 'ville', 'dest_city')

# %% [markdown]
# ### Cleanse & split normalized city names

# %%
regreplace = r"\((.*?)\)"
regsplit = r'/|,|\&| et | puis |\+| and | - |;'
df['dest_city'] = df['dest_city'].str.replace(regreplace,"").str.split(regsplit)
df = df.explode('dest_city')
df['dest_city'] = df['dest_city'].str.replace("\d", "")
df['dest_city'] = df['dest_city'].str.strip()

# %%
#df['dest_city'].sample(30)

# %% [markdown]
# ### Geocode city names

# %% [markdown]
# https://operations.osmfoundation.org/policies/nominatim/

# %%
def geocode(x, keys=['country_code', 'city', 'lat', 'lng', 'accuracy', 'confidence']):
    res = geocoder.osm(x).json
    time.sleep(2.0)
    return {k: (res or {}).get(k) for k in keys}

# %%
city = pd.DataFrame(list(df['from_city'].dropna().unique()) + list(df['dest_city'].unique()), columns=['city'])
city['city'].sample(30).values
# Out:
# array(['uppsala', 'bale', 'espagne', 'limerick', 'braunschweig',
#        'djibouti', 'stanford', 'palaikastro sitias', 'reaading', 'ulcinj',
#        'hong kong', 'new york city', 'campomoro', 'differentes villes',
#        'mainz', 'nazca', 'paray-le-monial', 'winterthur', 'marrakech',
#        'kalmar', 'wadi mussa', 'pontresina', 'marseille', 'il', 'tijuana',
#        'atlanta', 'nyiregyhaza', 'taichung', 'athenes', 'modena'],
#       dtype=object)

# %%
city.index
# Out:
# RangeIndex(start=0, stop=1268, step=1)

# %%
#citygc = city['city'].apply(geocode).apply(pd.Series)
#citygc.to_pickle('geocoded.pickle')
citygc = pd.read_pickle('geocoded.pickle')
citygc['country_code'] = citygc['country_code'].str.upper()
citygc = citygc.rename(columns={'city': 'citycoded', 'country_code': 'ISO2'})

# %%
geocoded = pd.concat([city, citygc], axis=1).drop_duplicates('city')
geocoded
# Out:
#                        city  ISO2                                 citycoded  \
# 0                 bruxelles    BE         Ville de Bruxelles - Stad Brussel
# 1                 charleroi    BE                                 Charleroi
# 2                     paris    FR                                     Paris
# 3                casablanca    MA  Casablanca ⵜⴰⴷⴷⴰⵔⵜ ⵜⵓⵎⵍⵉⵍⵜ الدار البيضاء
# 4                   reading    GB                                      None
# ...                     ...   ...                                       ...
# 1263         stadtoldendorf    DE                            Stadtoldendorf
# 1264  longueil-sainte-marie    FR                     Longueil-Sainte-Marie
# 1265             montpellie  None                                      None
# 1266                   otsu    JP                                      None
# 1267                athenes    GR                                     Αθήνα
#
#             lat         lng  accuracy  confidence
# 0     50.843671    4.367437  0.777530         4.0
# 1     50.412033    4.443624  0.668664         3.0
# 2     48.856697    2.351462  0.931710         2.0
# 3     33.595063   -7.618777  0.717325         1.0
# 4     51.451495   -0.983634  0.670144         4.0
# ...         ...         ...       ...         ...
# 1263  51.884211    9.625220  0.528807         4.0
# 1264  49.357664    2.717691  0.849620         5.0
# 1265        NaN         NaN       NaN         NaN
# 1266  35.004710  135.868674  0.532413         1.0
# 1267  37.983941   23.728305  0.732723         1.0
#
# [1204 rows x 7 columns]

# %%
df['from_city'] = df['from_city'].fillna('bruxelles')

# %%
df = df.merge(geocoded.add_prefix('from_'), how='left')#, left_on='from_city', right_on='from_city')
df = df.merge(geocoded.add_prefix('dest_'), how='left')#, left_on='dest_city', right_on='from_city')

# %%
df = df.reset_index().rename(columns={'index': 'travel_id'})
df
# Out:
#       travel_id  mission_id      debut        fin pays_origine ville_origine  \
# 0             0           0 2010-05-28 2010-06-01          NaN           NaN
# 1             1           0 2010-05-28 2010-06-01          NaN           NaN
# 2             2           1 2010-06-22 2010-07-08          NaN           NaN
# 3             3           2 2010-06-22 2010-07-08          NaN           NaN
# 4             4           3 2010-07-12 2010-07-17          NaN           NaN
# ...         ...         ...        ...        ...          ...           ...
# 6672       6672        6126 2020-02-23 2020-02-28     Belgique     Bruxelles
# 6673       6673        6127 2020-02-16 2020-02-18     Belgique     Bruxelles
# 6674       6674        6128 2020-03-02 2020-03-03     Pays-Bas     Amsterdam
# 6675       6675        6129 2020-01-28 2020-02-06     Belgique     Bruxelles
# 6676       6676        6129 2020-01-28 2020-02-06     Belgique     Bruxelles
#
#                  pays                           ville  \
# 0     Grande Bretagne                  Londres/Oxford
# 1     Grande Bretagne                  Londres/Oxford
# 2         Royaume-Uni                         Londres
# 3         Royaume-Uni                         Londres
# 4         Royaume-Uni                         Londres
# ...               ...                             ...
# 6672           France  Toulouse/Perpignan/Montpellier
# 6673           France                          Pessac
# 6674           France                           Paris
# 6675       États-Unis         Washington, Chapel Hill
# 6676       États-Unis         Washington, Chapel Hill
#
#                                                    lieu  \
# 0                 Oxford University — All Souls College
# 1                 Oxford University — All Souls College
# 2     Archives du Royal Opera House Covent GardenArc...
# 3     Archives du Royal Opera House Covent GardenArc...
# 4     Archives du Royal Opera House Covent GardenArc...
# ...                                                 ...
# 6672                                 AgroParisTech [FR]
# 6673                   Université de Bordeaux-Montaigne
# 6674                                               OCDE
# 6675                  Abilene Christian University [US]
# 6676                  Abilene Christian University [US]
#
#              mode_deplacement  ...   from_lat  from_lng from_accuracy  \
# 0                         NaN  ...  50.843671  4.367437      0.777530
# 1                         NaN  ...  50.843671  4.367437      0.777530
# 2                         NaN  ...  50.843671  4.367437      0.777530
# 3                         NaN  ...  50.843671  4.367437      0.777530
# 4                         NaN  ...  50.843671  4.367437      0.777530
# ...                       ...  ...        ...       ...           ...
# 6672                    train  ...  50.843671  4.367437      0.777530
# 6673                    train  ...  50.843671  4.367437      0.777530
# 6674                    train  ...  52.372760  4.893604      0.826813
# 6675  avion_long_courrier_eco  ...  50.843671  4.367437      0.777530
# 6676  avion_long_courrier_eco  ...  50.843671  4.367437      0.777530
#
#       from_confidence dest_ISO2 dest_citycoded   dest_lat   dest_lng  \
# 0                 4.0        GB         London  51.507322  -0.127647
# 1                 4.0        GB         Oxford  51.752013  -1.257850
# 2                 4.0        GB         London  51.507322  -0.127647
# 3                 4.0        GB         London  51.507322  -0.127647
# 4                 4.0        GB         London  51.507322  -0.127647
# ...               ...       ...            ...        ...        ...
# 6672              4.0        FR    Montpellier  43.611242   3.876734
# 6673              4.0        FR         Pessac  44.805615  -0.630840
# 6674              1.0        FR          Paris  48.856697   2.351462
# 6675              4.0        US     Washington  38.894893 -77.036553
# 6676              4.0        US    Chapel Hill  35.913154 -79.055780
#
#      dest_accuracy dest_confidence
# 0         0.830783             1.0
# 1         0.760604             4.0
# 2         0.830783             1.0
# 3         0.830783             1.0
# 4         0.830783             1.0
# ...            ...             ...
# 6672      0.741204             4.0
# 6673      0.549654             4.0
# 6674      0.931710             2.0
# 6675      0.849289             1.0
# 6676      0.746859             4.0
#
# [6677 rows x 30 columns]

# %% [markdown]
# ### Compute distance using Geodesic
#
# Avoid cartesian computation when dealing with geographic information unless your projection system is compatible with (reasonable on a small portion of the world uniquely).
# Plane travels have a radius increased by 10 km when distance is appreciable, should quantify how it does affect precision before path uncertainty.

# %%
def point(x, lat, lon):
    if x[lat]: 
        return (x[lat], x[lon])

# %%
df['from_point'] = df.apply(lambda x: point(x, 'from_lat', 'from_lng'), axis=1)
df['dest_point'] = df.apply(lambda x: point(x, 'dest_lat', 'dest_lng'), axis=1)

# %%
def distance(x):
    try:
        return geodesic(x['from_point'], x['dest_point'], ellipsoid='WGS-84').kilometers
    except:
        pass

# %%
df['distance'] = df.apply(distance, axis=1)

# %%
df.sample(10)
# Out:
#       travel_id  mission_id      debut        fin pays_origine ville_origine  \
# 5318       5318        4850 2019-01-27 2019-01-29     Belgique     Bruxelles
# 4132       4132        3746 2018-04-11 2018-04-16     Belgique     Bruxelles
# 3176       3176        2866 2017-04-11 2017-04-20          NaN           NaN
# 3805       3805        3443 2017-10-19 2017-10-21          NaN           NaN
# 4210       4210        3818 2018-03-15 2018-03-15     Belgique     Bruxelles
# 6387       6387        5866 2018-11-04 2020-03-04     Belgique     Bruxelles
# 2581       2581        2328 2016-06-10 2016-06-13          NaN           NaN
# 4137       4137        3751 2018-02-10 2018-02-15     Belgique     Bruxelles
# 5071       5071        4622 2018-11-20 2018-11-22     Belgique     Bruxelles
# 3515       3515        3175 2017-06-29 2017-07-06          NaN           NaN
#
#                                   pays                    ville  \
# 5318                            Italie                     Rome
# 4132                       Royaume-Uni                Cambridge
# 3176                            France                   Aleria
# 3805                            France                    Paris
# 4210                            France                    Paris
# 6387  République Démocratique du Congo  Kisangani, Wanie-Rukula
# 2581                            France                    Paris
# 4137                            Suisse                   Genčve
# 5071                       Royaume-Uni                   Londre
# 3515           France et Grčce (Cręte)      Paris, divers Cręte
#
#                                                    lieu  \
# 5318                 Universitŕ di Roma - "La Sapienza"
# 4132                       University of Cambridge [GB]
# 3176                                      Site d'Aléria
# 3805                 IHA - Institut historique allemand
# 4210                                          Eurogip
# 6387                       Université de Kisangani [CD]
# 2581                                               FIDH
# 4137                                                OMC
# 5071  University College London, University of Londo...
# 3515                                                 na
#
#              mode_deplacement  ... from_confidence dest_ISO2 dest_citycoded  \
# 5318    avion_courte_distance  ...             4.0        IT           Roma
# 4132                    train  ...             4.0        GB      Cambridge
# 3176                      NaN  ...             4.0        FR         Aléria
# 3805                      NaN  ...             4.0        FR          Paris
# 4210                    train  ...             4.0        FR          Paris
# 6387  avion_long_courrier_eco  ...             4.0        CD           None
# 2581                      NaN  ...             4.0        FR          Paris
# 4137    avion_courte_distance  ...             4.0      None           None
# 5071                    train  ...             4.0        GB         London
# 3515                      NaN  ...             4.0        GR           None
#
#        dest_lat   dest_lng dest_accuracy dest_confidence  \
# 5318  41.893320  12.482932      0.789611             1.0
# 4132  52.203482   0.123582      0.742767             4.0
# 3176  42.113572   9.514473      0.513821             4.0
# 3805  48.856697   2.351462      0.931710             2.0
# 4210  48.856697   2.351462      0.931710             2.0
# 6387   0.193749  25.527917      0.500000             4.0
# 2581  48.856697   2.351462      0.931710             2.0
# 4137        NaN        NaN           NaN             NaN
# 5071  51.507322  -0.127647      0.830783             1.0
# 3515  35.406788  25.018286      0.101000            10.0
#
#                             from_point                dest_point     distance
# 5318  (50.8436709, 4.3674366933879565)  (41.8933203, 12.4829321)  1173.045388
# 4132  (50.8436709, 4.3674366933879565)   (52.2034823, 0.1235817)   331.054075
# 3176  (50.8436709, 4.3674366933879565)   (42.1135718, 9.5144732)  1047.195535
# 3805  (50.8436709, 4.3674366933879565)   (48.8566969, 2.3514616)   264.293514
# 4210  (50.8436709, 4.3674366933879565)   (48.8566969, 2.3514616)   264.293514
# 6387  (50.8436709, 4.3674366933879565)   (0.1937489, 25.5279174)  5958.903853
# 2581  (50.8436709, 4.3674366933879565)   (48.8566969, 2.3514616)   264.293514
# 4137  (50.8436709, 4.3674366933879565)                (nan, nan)          NaN
# 5071  (50.8436709, 4.3674366933879565)  (51.5073219, -0.1276474)   322.849447
# 3515  (50.8436709, 4.3674366933879565)  (35.4067884, 25.0182857)  2385.025681
#
# [10 rows x 33 columns]
