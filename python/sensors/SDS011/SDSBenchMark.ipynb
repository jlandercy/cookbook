# %%
import pathlib
import json
import re

# %%
import influxdb
import pandas as pd
import matplotlib.pyplot as plt

# %%
from odapi.connectors import Irceline
from odapi.settings import settings
settings.logger.setLevel(50)

# %% [markdown]
# ## Parameters

# %%
t0 = pd.Timestamp('2020-06-22 13:00:00', tz='CET').tz_convert('UTC')
t0
# Out:
# Timestamp('2020-06-22 11:00:00+0000', tz='UTC')

# %%
t1 = pd.Timestamp.utcnow()
t1
# Out:
# Timestamp('2020-07-01 07:01:43.186257+0000', tz='UTC')

# %% [markdown]
# ## Irceline Reference

# %%
cref = Irceline()

# %%
sel = cref.select(sitekey='41', measurekey='PM')

# %%
sel.shape
# Out:
# (11, 25)

# %%
recs = cref.get_records(sel, start=t0, stop=t1)

# %%
dref = recs.merge(sel[['serieid', 'seriekey']]).pivot_table(index='start', columns='seriekey', values='value')

# %%
dref.tail()
# Out:
# seriekey                   PM-10.0/41B011 (µg/m³)  PM-10.0/41MEU1 (µg/m³)  \
# start
# 2020-07-01 00:00:00+00:00                     NaN                     7.5
# 2020-07-01 01:00:00+00:00                     NaN                     5.5
# 2020-07-01 02:00:00+00:00                     NaN                     7.5
# 2020-07-01 03:00:00+00:00                     NaN                     8.0
# 2020-07-01 04:00:00+00:00                     1.5                     8.5
#
# seriekey                   PM-10.0/41N043 (µg/m³)  PM-10.0/41R001 (µg/m³)  \
# start
# 2020-07-01 00:00:00+00:00                     NaN                     3.0
# 2020-07-01 01:00:00+00:00                     4.5                     5.5
# 2020-07-01 02:00:00+00:00                    10.5                     3.5
# 2020-07-01 03:00:00+00:00                     7.5                     3.0
# 2020-07-01 04:00:00+00:00                    10.5                     4.5
#
# seriekey                   PM-10.0/41R012 (µg/m³)  PM-10.0/41WOL1 (µg/m³)  \
# start
# 2020-07-01 00:00:00+00:00                     9.5                     NaN
# 2020-07-01 01:00:00+00:00                     NaN                     NaN
# 2020-07-01 02:00:00+00:00                     NaN                     NaN
# 2020-07-01 03:00:00+00:00                     NaN                     NaN
# 2020-07-01 04:00:00+00:00                    10.0                     NaN
#
# seriekey                   PM-2.5/41B011 (µg/m³)  PM-2.5/41MEU1 (µg/m³)  \
# start
# 2020-07-01 00:00:00+00:00                    NaN                   5.80
# 2020-07-01 01:00:00+00:00                    NaN                   4.35
# 2020-07-01 02:00:00+00:00                    NaN                   6.85
# 2020-07-01 03:00:00+00:00                    NaN                   6.30
# 2020-07-01 04:00:00+00:00                    0.6                   4.45
#
# seriekey                   PM-2.5/41N043 (µg/m³)  PM-2.5/41R001 (µg/m³)  \
# start
# 2020-07-01 00:00:00+00:00                    NaN                   2.60
# 2020-07-01 01:00:00+00:00                   2.25                   4.65
# 2020-07-01 02:00:00+00:00                   8.95                   2.50
# 2020-07-01 03:00:00+00:00                   5.45                   1.40
# 2020-07-01 04:00:00+00:00                   7.70                   2.45
#
# seriekey                   PM-2.5/41R012 (µg/m³)
# start
# 2020-07-01 00:00:00+00:00                   6.00
# 2020-07-01 01:00:00+00:00                   2.45
# 2020-07-01 02:00:00+00:00                   0.90
# 2020-07-01 03:00:00+00:00                   3.75
# 2020-07-01 04:00:00+00:00                   7.60

# %% [markdown]
# ## SDS Benchmark

# %%
with pathlib.Path('C:/Users/admin/udlog/influx.json').open() as fh:
    client = influxdb.InfluxDBClient(**json.load(fh))

# %%
client.ping()
# Out:
# '1.8.0'

# %%
query = """
SELECT mean(pm25) AS pm25, mean(pm10) AS pm10
FROM "home"
WHERE time >= '{start:}' AND time < '{stop:}'
GROUP BY time(1h)
""".format(start=t0.isoformat(), stop=t1.isoformat())
print(query)
# Out:
# SELECT mean(pm25) AS pm25, mean(pm10) AS pm10
# FROM "home"
# WHERE time >= '2020-06-22T11:00:00+00:00' AND time < '2020-07-01T07:01:43.186257+00:00'
# GROUP BY time(1h)

# %%
r = client.query(query).raw['series'][0]

# %%
dsds = pd.DataFrame(r['values'], columns=r['columns'])
dsds['time'] = pd.to_datetime(dsds['time'])
dsds = dsds.set_index('time')
dsds.columns = ['PM-2.5/Home (µg/m³)', 'PM-10.0/Home (µg/m³)']
dsds.tail()
# Out:
#                            PM-2.5/Home (µg/m³)  PM-10.0/Home (µg/m³)
# time
# 2020-07-01 03:00:00+00:00            14.692592             23.833408
# 2020-07-01 04:00:00+00:00            15.073395             22.080518
# 2020-07-01 05:00:00+00:00             9.610401             14.147967
# 2020-07-01 06:00:00+00:00             9.463243             14.342395
# 2020-07-01 07:00:00+00:00             6.315385             10.873077

# %% [markdown]
# ## Data Merge

# %%
df = pd.concat([dref, dsds], axis=1)
df.tail()
# Out:
#                            PM-10.0/41B011 (µg/m³)  PM-10.0/41MEU1 (µg/m³)  \
# 2020-07-01 03:00:00+00:00                     NaN                     8.0
# 2020-07-01 04:00:00+00:00                     1.5                     8.5
# 2020-07-01 05:00:00+00:00                     NaN                     NaN
# 2020-07-01 06:00:00+00:00                     NaN                     NaN
# 2020-07-01 07:00:00+00:00                     NaN                     NaN
#
#                            PM-10.0/41N043 (µg/m³)  PM-10.0/41R001 (µg/m³)  \
# 2020-07-01 03:00:00+00:00                     7.5                     3.0
# 2020-07-01 04:00:00+00:00                    10.5                     4.5
# 2020-07-01 05:00:00+00:00                     NaN                     NaN
# 2020-07-01 06:00:00+00:00                     NaN                     NaN
# 2020-07-01 07:00:00+00:00                     NaN                     NaN
#
#                            PM-10.0/41R012 (µg/m³)  PM-10.0/41WOL1 (µg/m³)  \
# 2020-07-01 03:00:00+00:00                     NaN                     NaN
# 2020-07-01 04:00:00+00:00                    10.0                     NaN
# 2020-07-01 05:00:00+00:00                     NaN                     NaN
# 2020-07-01 06:00:00+00:00                     NaN                     NaN
# 2020-07-01 07:00:00+00:00                     NaN                     NaN
#
#                            PM-2.5/41B011 (µg/m³)  PM-2.5/41MEU1 (µg/m³)  \
# 2020-07-01 03:00:00+00:00                    NaN                   6.30
# 2020-07-01 04:00:00+00:00                    0.6                   4.45
# 2020-07-01 05:00:00+00:00                    NaN                    NaN
# 2020-07-01 06:00:00+00:00                    NaN                    NaN
# 2020-07-01 07:00:00+00:00                    NaN                    NaN
#
#                            PM-2.5/41N043 (µg/m³)  PM-2.5/41R001 (µg/m³)  \
# 2020-07-01 03:00:00+00:00                   5.45                   1.40
# 2020-07-01 04:00:00+00:00                   7.70                   2.45
# 2020-07-01 05:00:00+00:00                    NaN                    NaN
# 2020-07-01 06:00:00+00:00                    NaN                    NaN
# 2020-07-01 07:00:00+00:00                    NaN                    NaN
#
#                            PM-2.5/41R012 (µg/m³)  PM-2.5/Home (µg/m³)  \
# 2020-07-01 03:00:00+00:00                   3.75            14.692592
# 2020-07-01 04:00:00+00:00                   7.60            15.073395
# 2020-07-01 05:00:00+00:00                    NaN             9.610401
# 2020-07-01 06:00:00+00:00                    NaN             9.463243
# 2020-07-01 07:00:00+00:00                    NaN             6.315385
#
#                            PM-10.0/Home (µg/m³)
# 2020-07-01 03:00:00+00:00             23.833408
# 2020-07-01 04:00:00+00:00             22.080518
# 2020-07-01 05:00:00+00:00             14.147967
# 2020-07-01 06:00:00+00:00             14.342395
# 2020-07-01 07:00:00+00:00             10.873077

# %% [markdown]
# ## Render

# %%
remeas = re.compile('([\w\-\.]{2,8})/.*(\(.*\))')
resite = re.compile('/([\w]{4,6}) ')

# %%
fig, axe = plt.subplots()
axe = df.filter(regex='2.5').plot(ax=axe)
axe.legend(bbox_to_anchor=(1,1))
axe.set_ylim([0, 100])
axe.grid()
labels = [s.get_text() for s in axe.get_legend().get_texts()]
axe.set_title("Concentration Time Series on [{:%Y-%m-%d}; {:%Y-%m-%d}]".format(t0, t1))
axe.set_xlabel("Time")
axe.set_ylabel('{} {}'.format(*remeas.search(labels[0]).groups()))
_ = fig.text(0.92, 0.15, "Sources: Irceline API\nCredits: J. Landercy", rotation=90)

# %%
fig, axe = plt.subplots()
axe = df.filter(regex='10.0').plot(ax=axe)
axe.legend(bbox_to_anchor=(1,1))
axe.set_ylim([0, 100])
axe.grid()
labels = [s.get_text() for s in axe.get_legend().get_texts()]
axe.set_title("Concentration Time Series on [{:%Y-%m-%d}; {:%Y-%m-%d}]".format(t0, t1))
axe.set_xlabel("Time")
axe.set_ylabel('{} {}'.format(*remeas.search(labels[0]).groups()))
_ = fig.text(0.92, 0.15, "Sources: Irceline API\nCredits: J. Landercy", rotation=90)

# %%
fig, axe = plt.subplots()
axe = df.filter(regex='10.0').boxplot(rot=90, ax=axe)
axe.set_ylim([0, 50])
labels = [s.get_text() for s in axe.get_xticklabels()]
axe.set_xticklabels([resite.search(s).group(1) for s in labels])
axe.set_title("Concentration Distributions on [{:%Y-%m-%d}; {:%Y-%m-%d}]".format(t0, t1))
axe.set_xlabel("Sites")
axe.set_ylabel('{} {}'.format(*remeas.search(labels[0]).groups()))
_ = fig.text(0.92, 0.15, "Sources: Irceline API\nCredits: J. Landercy", rotation=90)

# %%
fig, axe = plt.subplots()
axe = df.filter(regex='2.5').boxplot(rot=90, ax=axe)
axe.set_ylim([0, 50])
labels = [s.get_text() for s in axe.get_xticklabels()]
axe.set_xticklabels([resite.search(s).group(1) for s in labels])
axe.set_title("Concentration Distributions on [{:%Y-%m-%d}; {:%Y-%m-%d}]".format(t0, t1))
axe.set_xlabel("Sites")
axe.set_ylabel('{} {}'.format(*remeas.search(labels[0]).groups()))
_ = fig.text(0.92, 0.15, "Sources: Irceline API\nCredits: J. Landercy", rotation=90)
