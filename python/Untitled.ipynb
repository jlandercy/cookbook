# %%
import pandas as pd
import geopandas as gpd
import contextily as cx

# %%
df = pd.DataFrame([{"lon": 4.35, "lat": 50.85}])
df = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat), crs=4326).to_crs(31370)
df2 = df.copy()
df2['geometry'] = df2['geometry'].buffer(1500)

# %%
df
# Out:
#     lon    lat                       geometry
# 0  4.35  50.85  POINT (148679.447 171066.810)

# %%
axe = df.to_crs(epsg=3857).plot(figsize=(10, 10))
df2.to_crs(epsg=3857).plot(alpha=0.35, ax=axe)
cx.add_basemap(axe, zoom=16)
axe.set_axis_off()
