# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# %% [markdown]
# https://stackoverflow.com/questions/77813137/how-to-centre-observational-data-onto-predicted-isochrone-data-in-python

# %%
data = pd.read_csv("https://pastebin.com/raw/LCmxG9Lz")
model = pd.read_csv("https://pastebin.com/raw/MH9HBeJA")

# %%
data.sample()
# Out:
#               G   Bp-Rp
# 12413  4.422938  0.9291

# %%
fig, axe = plt.subplots()
axe.scatter(data["G"], data["Bp-Rp"], marker=".")
#axe.plot(model["G"], model["Bp-Rp"], color="orange")
axe.grid()

# %%
kernel = 1.0 * RBF()
model = GaussianProcessRegressor(kernel=kernel, alpha=0.01)

# %%
X = data[["G"]].values
y = data["Bp-Rp"].values

# %%
model.fit(X, y)

# %%
xlin = np.linspace(2, 7, 200)
