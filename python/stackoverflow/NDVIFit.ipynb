# %% [markdown]
# https://stackoverflow.com/questions/78001882/assymetric-gaussian-funciton-fitting-in-python-for-time-series

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

# %%
ts = np.array([
    0.8821, 0.7118, 0.6271, 0.2289, 0.2003, 0.1658, 0.3492, 0.3385, 0.7882, 0.8434,
    0.8691, 0.8546, 0.8451, 0.8419,0.8524, 0.8249, 0.8573, 0.8339, 0.8026, 0.7707,
    0.7758, 0.7362, 0.6913, 0.6461, 0.4875, 0.3913, 0.2732, 0.2132, 0.2077, 0.1861
])
doy_vector = np.arange(0, ts.size)

# %%
def g(t, a1, a2, a3, a4, a5):
    return np.where(t > a1, np.exp(-((t - a1) / a2)**a3), np.exp(-((a1 - t) / a4)**a5))

def f(t, c1, c2, a1, a2, a3, a4, a5):
    return c1 + c2 * g(t, a1, a2, a3, a4, a5)

# %%
p = [1, 1, 50, 10, 2, 10, 2]

# %%
f(doy_vector, *p)
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.00000001, 1.00000002, 1.00000005,
#        1.00000011, 1.00000025, 1.00000054, 1.00000113, 1.00000235,
#        1.00000479, 1.00000954, 1.00001864, 1.00003571, 1.00006705,
#        1.00012341, 1.00022263, 1.00039367, 1.00068233, 1.00115923,
#        1.00193045, 1.00315111, 1.00504176, 1.00790705, 1.01215518])

# %%
fig, axe = plt.subplots()
axe.plot(doy_vector, ts)
