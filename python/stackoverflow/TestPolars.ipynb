# %%
import polars as pl

# %%
uri = "postgresql://pesticides:pesticides@localhost:5432/pesticides"

# %%
substances = pl.read_database_uri(query="SELECT * FROM chemistry_substance;", uri=uri)

# %%
identifiers = pl.read_database_uri(query="SELECT * FROM chemistry_substanceidentifier;", uri=uri)

# %%
types = pl.read_database_uri(query="SELECT * FROM chemistry_substanceidentifiertype;", uri=uri)
