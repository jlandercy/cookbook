# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import special

# %% [markdown]
#  - https://stackoverflow.com/questions/79543132/half-life-of-po212-in-python-by-modelling-quantum-tunneling
#  - https://www.hsc.edu.kw/student/materials/Physics/website/hyperphysics%20modified/hbase/nuclear/alpdet.html#c1
#  - https://www.hsc.edu.kw/student/materials/Physics/website/hyperphysics%20modified/hbase/nuclear/nucuni.html#c4

# %%
N_Po = 84
N_alpha = 2

# %%
R = 1.2 * (np.power(4, 1 / 3) + np.power(212 - 4, 1 / 3))
R
# Out:
# np.float64(9.014871826539528)
