# %%
import sympy as sp

# %%
x = sp.Symbol("x")

# %%
p = 3 * x ** 3 * (x + 5) * (2 - x) ** 2

# %%
p
# Out:
# 3*x**3*(2 - x)**2*(x + 5)

# %%
sp.expand(p)
# Out:
# 3*x**6 + 3*x**5 - 48*x**4 + 60*x**3

# %%
sp.factor(_)
# Out:
# 3*x**3*(x - 2)**2*(x + 5)
