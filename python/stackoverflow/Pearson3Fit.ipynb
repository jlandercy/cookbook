# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
law = stats.pearson3(skew=0.85)

# %%
data = law.rvs(3_000)

# %%
fig, axe = plt.subplots()
axe.hist(data)
# Out:
# (array([210., 690., 787., 649., 351., 192.,  73.,  24.,  18.,   6.]),
#  array([-1.93672853, -1.28047493, -0.62422133,  0.03203227,  0.68828588,
#          1.34453948,  2.00079308,  2.65704668,  3.31330028,  3.96955388,
#          4.62580748]),
#  <BarContainer object of 10 artists>)

# %%
stats.pearson3.fit(data, floc=0., fscale=1.)
# Out:
# (np.float64(0.9296874999999999), 0.0, 1.0)
