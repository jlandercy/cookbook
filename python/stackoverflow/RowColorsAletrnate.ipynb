# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([
    ['A1',  'B2',  'C1',   'D1'],
    ['A2',  'B2',  'C2',   'D2'],
    ['A3',  'B2',  'C3',   'D3'],
    ['A4',  'B4',  'C4',   'D4'],
    ['A5',  'B4',  'C5',   'D5'],
    ['A6',  'B4',  'C6',   'D6'],
    ['A7',  'B6',  'C7',   'D7'],
    ['A8',  'B6',  'C8',   'D8'],
    ['A9',  'B10', 'C9',   'D9'],
    ['A10', 'B10', 'C10',  'D10'],
    ['A11', 'B10', 'C11',  'D11'],
    ['A12', 'B10', 'C12',  'D12'],
    ['A13', 'B14', 'C13',  'D13'],
    ['A14', 'B14', 'C14',  'D14'],
    ['A15', 'B14', 'C15',  'D15']
], 
   columns=['c1', 'c2', 'c3', 'c4']
)

# %%
df
# Out:
#      c1   c2   c3   c4
# 0    A1   B2   C1   D1
# 1    A2   B2   C2   D2
# 2    A3   B2   C3   D3
# 3    A4   B4   C4   D4
# 4    A5   B4   C5   D5
# 5    A6   B4   C6   D6
# 6    A7   B6   C7   D7
# 7    A8   B6   C8   D8
# 8    A9  B10   C9   D9
# 9   A10  B10  C10  D10
# 10  A11  B10  C11  D11
# 11  A12  B10  C12  D12
# 12  A13  B14  C13  D13
# 13  A14  B14  C14  D14
# 14  A15  B14  C15  D15

# %%
keys = df["c2"].unique().tolist()
color = df["c2"].apply(lambda x: keys.index(x) % 2)
color = color.replace({0: 'background-color: green', 1: ''})
df.style.apply(lambda x: color)
# Out:
# <style type="text/css">
# #T_6b63d_row0_col0, #T_6b63d_row0_col1, #T_6b63d_row0_col2, #T_6b63d_row0_col3, #T_6b63d_row1_col0, #T_6b63d_row1_col1, #T_6b63d_row1_col2, #T_6b63d_row1_col3, #T_6b63d_row2_col0, #T_6b63d_row2_col1, #T_6b63d_row2_col2, #T_6b63d_row2_col3, #T_6b63d_row6_col0, #T_6b63d_row6_col1, #T_6b63d_row6_col2, #T_6b63d_row6_col3, #T_6b63d_row7_col0, #T_6b63d_row7_col1, #T_6b63d_row7_col2, #T_6b63d_row7_col3, #T_6b63d_row12_col0, #T_6b63d_row12_col1, #T_6b63d_row12_col2, #T_6b63d_row12_col3, #T_6b63d_row13_col0, #T_6b63d_row13_col1, #T_6b63d_row13_col2, #T_6b63d_row13_col3, #T_6b63d_row14_col0, #T_6b63d_row14_col1, #T_6b63d_row14_col2, #T_6b63d_row14_col3 {
#   background-color: green;
# }
# </style>
# <table id="T_6b63d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b63d_level0_col0" class="col_heading level0 col0" >c1</th>
#       <th id="T_6b63d_level0_col1" class="col_heading level0 col1" >c2</th>
#       <th id="T_6b63d_level0_col2" class="col_heading level0 col2" >c3</th>
#       <th id="T_6b63d_level0_col3" class="col_heading level0 col3" >c4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b63d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b63d_row0_col0" class="data row0 col0" >A1</td>
#       <td id="T_6b63d_row0_col1" class="data row0 col1" >B2</td>
#       <td id="T_6b63d_row0_col2" class="data row0 col2" >C1</td>
#       <td id="T_6b63d_row0_col3" class="data row0 col3" >D1</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b63d_row1_col0" class="data row1 col0" >A2</td>
#       <td id="T_6b63d_row1_col1" class="data row1 col1" >B2</td>
#       <td id="T_6b63d_row1_col2" class="data row1 col2" >C2</td>
#       <td id="T_6b63d_row1_col3" class="data row1 col3" >D2</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b63d_row2_col0" class="data row2 col0" >A3</td>
#       <td id="T_6b63d_row2_col1" class="data row2 col1" >B2</td>
#       <td id="T_6b63d_row2_col2" class="data row2 col2" >C3</td>
#       <td id="T_6b63d_row2_col3" class="data row2 col3" >D3</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6b63d_row3_col0" class="data row3 col0" >A4</td>
#       <td id="T_6b63d_row3_col1" class="data row3 col1" >B4</td>
#       <td id="T_6b63d_row3_col2" class="data row3 col2" >C4</td>
#       <td id="T_6b63d_row3_col3" class="data row3 col3" >D4</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6b63d_row4_col0" class="data row4 col0" >A5</td>
#       <td id="T_6b63d_row4_col1" class="data row4 col1" >B4</td>
#       <td id="T_6b63d_row4_col2" class="data row4 col2" >C5</td>
#       <td id="T_6b63d_row4_col3" class="data row4 col3" >D5</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b63d_row5_col0" class="data row5 col0" >A6</td>
#       <td id="T_6b63d_row5_col1" class="data row5 col1" >B4</td>
#       <td id="T_6b63d_row5_col2" class="data row5 col2" >C6</td>
#       <td id="T_6b63d_row5_col3" class="data row5 col3" >D6</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b63d_row6_col0" class="data row6 col0" >A7</td>
#       <td id="T_6b63d_row6_col1" class="data row6 col1" >B6</td>
#       <td id="T_6b63d_row6_col2" class="data row6 col2" >C7</td>
#       <td id="T_6b63d_row6_col3" class="data row6 col3" >D7</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b63d_row7_col0" class="data row7 col0" >A8</td>
#       <td id="T_6b63d_row7_col1" class="data row7 col1" >B6</td>
#       <td id="T_6b63d_row7_col2" class="data row7 col2" >C8</td>
#       <td id="T_6b63d_row7_col3" class="data row7 col3" >D8</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b63d_row8_col0" class="data row8 col0" >A9</td>
#       <td id="T_6b63d_row8_col1" class="data row8 col1" >B10</td>
#       <td id="T_6b63d_row8_col2" class="data row8 col2" >C9</td>
#       <td id="T_6b63d_row8_col3" class="data row8 col3" >D9</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b63d_row9_col0" class="data row9 col0" >A10</td>
#       <td id="T_6b63d_row9_col1" class="data row9 col1" >B10</td>
#       <td id="T_6b63d_row9_col2" class="data row9 col2" >C10</td>
#       <td id="T_6b63d_row9_col3" class="data row9 col3" >D10</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6b63d_row10_col0" class="data row10 col0" >A11</td>
#       <td id="T_6b63d_row10_col1" class="data row10 col1" >B10</td>
#       <td id="T_6b63d_row10_col2" class="data row10 col2" >C11</td>
#       <td id="T_6b63d_row10_col3" class="data row10 col3" >D11</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6b63d_row11_col0" class="data row11 col0" >A12</td>
#       <td id="T_6b63d_row11_col1" class="data row11 col1" >B10</td>
#       <td id="T_6b63d_row11_col2" class="data row11 col2" >C12</td>
#       <td id="T_6b63d_row11_col3" class="data row11 col3" >D12</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6b63d_row12_col0" class="data row12 col0" >A13</td>
#       <td id="T_6b63d_row12_col1" class="data row12 col1" >B14</td>
#       <td id="T_6b63d_row12_col2" class="data row12 col2" >C13</td>
#       <td id="T_6b63d_row12_col3" class="data row12 col3" >D13</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6b63d_row13_col0" class="data row13 col0" >A14</td>
#       <td id="T_6b63d_row13_col1" class="data row13 col1" >B14</td>
#       <td id="T_6b63d_row13_col2" class="data row13 col2" >C14</td>
#       <td id="T_6b63d_row13_col3" class="data row13 col3" >D14</td>
#     </tr>
#     <tr>
#       <th id="T_6b63d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6b63d_row14_col0" class="data row14 col0" >A15</td>
#       <td id="T_6b63d_row14_col1" class="data row14 col1" >B14</td>
#       <td id="T_6b63d_row14_col2" class="data row14 col2" >C15</td>
#       <td id="T_6b63d_row14_col3" class="data row14 col3" >D15</td>
#     </tr>
#   </tbody>
# </table>
