# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## References
#
#  - https://en.wikipedia.org/wiki/Epicycloid
#  - https://en.wikipedia.org/wiki/Epitrochoid
#  - https://www.mathcurve.com/courbes2d.gb/epitrochoid/epitrochoid.shtml
#  - [Periodicty](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=3&ved=2ahUKEwje1q__2pTmAhUNdBQKHXPmAHYQFjACegQIAhAH&url=https%3A%2F%2Fwebcms3.cse.unsw.edu.au%2Ffiles%2F77a3632422040bb6f33386b1818982b7b9fc8fbe6de5f4f62eda4af9ee1fafd3%2Fattachment&usg=AOvVaw0JnCpkzzQltaJmRkVhWj5q)
#  - https://numpy.org/
#  - https://matplotlib.org/
#
# ## Parametrization
#
#
# $$x(\theta) = (R + r) \cos \theta \ - d \cos \left( \frac{R + r}{r} \theta \right)$$
# $$y (\theta) = (R + r) \sin \theta \ - d \sin \left( \frac{R + r}{r} \theta \right)$$
# $$T = \frac{r}{\gcd (R,r)}$$
# $$\theta \in [0;2T\pi[$$

# %%
R = 7
r = 4
d = 6

# %%
T = r/math.gcd(R, r)

# %%
t = np.linspace(0, 2*T*np.pi, 1000)

# %%
x = (R+r)*np.cos(t) - d*np.cos((R+r)/r*t)
y = (R+r)*np.sin(t) - d*np.sin((R+r)/r*t)

# %%
fig, axe = plt.subplots()
axe.plot(x, y)
axe.set_title("Epitrochoid")
axe.set_xlabel("x")
axe.set_ylabel("y")
axe.grid()
axe.set_aspect('equal')
