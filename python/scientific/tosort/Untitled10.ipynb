# %%
from odapi.connectors import Irceline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
c = Irceline()
# Out:
# 2020-06-10 12:39:11,774	odapi             	generic     	load        	DEBUG 	Load Settings C:\Users\jlanderc\Anaconda3\lib\site-packages\odapi-0.1.0-py3.7.egg\odapi\connectors\opendata\resources\irceline.json

# %%
s = c.select(measurekey='RH', sitekey='41R')
# Out:
# 2020-06-10 12:39:11,808	odapi             	api         	select      	DEBUG 	Selection Keys: {'measurekey': 'RH', 'sitekey': '41R'}
# 2020-06-10 12:39:13,705	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/?expanded=true
# 2020-06-10 12:39:14,584	odapi             	irceline    	get_metadata	DEBUG 	FRAME: (590, 38) metadata fetched
# 2020-06-10 12:39:14,616	odapi             	api         	select      	DEBUG 	Selected 2 row(s): {'10794', '10793'}

# %%
r = c.get_records(s, start='2017-01-01', stop='2020-01-01')
# Out:
# 2020-06-10 12:39:14,662	odapi             	timeseries  	prepare_parameters	DEBUG 	PARAM: {'identifiers': {'10794', '10793'}, 'stop': Timestamp('2020-01-01 00:00:00+0000', tz='UTC'), 'start': Timestamp('2017-01-01 00:00:00+0000', tz='UTC'), 'timerange': DatetimeIndex(['2017-01-01 00:00:00+00:00', '2017-01-02 00:00:00+00:00',
#                '2017-01-03 00:00:00+00:00', '2017-01-04 00:00:00+00:00',
#                '2017-01-05 00:00:00+00:00', '2017-01-06 00:00:00+00:00',
#                '2017-01-07 00:00:00+00:00', '2017-01-08 00:00:00+00:00',
#                '2017-01-09 00:00:00+00:00', '2017-01-10 00:00:00+00:00',
#                ...
#                '2019-12-23 00:00:00+00:00', '2019-12-24 00:00:00+00:00',
#                '2019-12-25 00:00:00+00:00', '2019-12-26 00:00:00+00:00',
#                '2019-12-27 00:00:00+00:00', '2019-12-28 00:00:00+00:00',
#                '2019-12-29 00:00:00+00:00', '2019-12-30 00:00:00+00:00',
#                '2019-12-31 00:00:00+00:00', '2020-01-01 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', length=1096, freq=None)}
# 2020-06-10 12:39:14,665	odapi             	timeseries  	prepare_parameters	DEBUG 	PARAM: {'identifiers': {'10794', '10793'}, 'stop': Timestamp('2020-01-01 00:00:00+0000', tz='UTC'), 'start': Timestamp('2017-01-01 01:00:00+0000', tz='UTC'), 'timerange': DatetimeIndex(['2017-01-01 01:00:00+00:00', '2017-01-01 00:00:00+00:00',
#                '2018-01-01 00:00:00+00:00', '2019-01-01 00:00:00+00:00',
#                '2020-01-01 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)}
# 2020-06-10 12:39:14,927	odapi             	irceline    	fetch       	DEBUG 	GET [400]: http://geo.irceline.be/sos/api/v1/timeseries/10794/getData/?timespan=2017-01-01T01:00Z/2017-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:14,930	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10794 on [2017-01-01 01:00:00+00:00;2017-01-01 00:00:00+00:00[
# 2020-06-10 12:39:15,340	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10794/getData/?timespan=2017-01-01T00:00Z/2018-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:15,343	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10794 on [2017-01-01 00:00:00+00:00;2018-01-01 00:00:00+00:00[
# 2020-06-10 12:39:15,850	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10794/getData/?timespan=2018-01-01T00:00Z/2019-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:15,854	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10794 on [2018-01-01 00:00:00+00:00;2019-01-01 00:00:00+00:00[
# 2020-06-10 12:39:16,618	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10794/getData/?timespan=2019-01-01T00:00Z/2020-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:16,756	odapi             	irceline    	fetch       	DEBUG 	GET [400]: http://geo.irceline.be/sos/api/v1/timeseries/10793/getData/?timespan=2017-01-01T01:00Z/2017-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:16,759	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10793 on [2017-01-01 01:00:00+00:00;2017-01-01 00:00:00+00:00[
# 2020-06-10 12:39:17,282	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10793/getData/?timespan=2017-01-01T00:00Z/2018-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:17,286	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10793 on [2017-01-01 00:00:00+00:00;2018-01-01 00:00:00+00:00[
# 2020-06-10 12:39:17,737	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10793/getData/?timespan=2018-01-01T00:00Z/2019-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:17,743	odapi             	irceline    	get_records 	WARNING	Empty selection: serieid=10793 on [2018-01-01 00:00:00+00:00;2019-01-01 00:00:00+00:00[
# 2020-06-10 12:39:18,355	odapi             	irceline    	fetch       	DEBUG 	GET [200]: http://geo.irceline.be/sos/api/v1/timeseries/10793/getData/?timespan=2019-01-01T00:00Z/2020-01-01T00:00Z&force_latest_values=true
# 2020-06-10 12:39:18,470	odapi             	irceline    	get_records 	DEBUG 	FRAME: 17520 record(s) fetched

# %%
d = r.merge(s[['serieid', 'seriekey']]).pivot_table(index='start', columns='seriekey', values='value')

# %%
d.to_pickle('rh.pickle')

# %%
d.plot()

# %%
bins = np.arange(0.,101., 10.)

# %%
axe = d.hist(density=1, bins=bins, sharex=True, sharey=True)
axe[0][0].set_xlim([0, 100])
# Out:
# (0, 100)

# %%
axe = d.hist(density=1, bins=bins, cumulative=True, sharex=True, sharey=True)
axe[0][0].set_xlim([0, 100])
# Out:
# (0, 100)
