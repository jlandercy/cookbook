# %%
import pathlib
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("../../../data/WBG/LifeExp.csv")
# Out:
#                                          Series Name     Series Code    Time  \
# 0            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1960.0
# 1            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1961.0
# 2            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1962.0
# 3            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1963.0
# 4            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1964.0
# 5            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1965.0
# 6            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1966.0
# 7            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1967.0
# 8            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1968.0
# 9            Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1969.0
# 10           Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1970.0
# ...
