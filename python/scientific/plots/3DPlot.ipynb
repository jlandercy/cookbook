# %%
import warnings
warnings.simplefilter('ignore')
import pathlib

# %%
import numpy as np
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.figsize'] = 1.25*np.array(mpl.rcParams['figure.figsize'])
import pandas as pd

# %%
from scipy import stats
from scipy import signal
import statsmodels as sm
import seaborn as sn

# %%
from scipy.optimize import minimize, rosen, rosen_der

# %%
def rosenbrock_factory(a, b):
    """
    Rosenbrock Function Factory
    """
    def rosenbrock(x, y):
        """
        Parametered Rosenbrock Function
        """
        return (a-x)**2+b*(y-x**2)**2
    return rosenbrock

# %%
f = rosenbrock_factory(1, 100)

# %%
x = np.linspace(-2,2, 1000)
y = np.linspace(-1,3, 1000)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

# %%
fig = plt.figure(figsize=(10,10))
axe = fig.gca(projection='3d')
surf = axe.plot_surface(X, Y, Z, cmap=cm.coolwarm, linewidth=1, antialiased=True)
axe.view_init(30, 30)
axe.set_xlabel(r"$x$")
axe.set_ylabel(r"$y$")
axe.set_zlabel(r"$z$")
xcset = axe.contour(X, Y, Z, zdir='x', offset=axe.get_xlim()[0], cmap=cm.coolwarm)
ycset = axe.contour(X, Y, Z, zdir='y', offset=axe.get_ylim()[0], cmap=cm.coolwarm)
zcset = axe.contour(X, Y, Z, zdir='z', offset=axe.get_zlim()[0], cmap=cm.coolwarm)

# %%
fig, axe = plt.subplots()
xcset = axe.contour(X, Y, Z, 30, cmap=cm.coolwarm)

# %%
fig, axe = plt.subplots()
xcset = axe.contour(Z, X, Y, 30, cmap=cm.coolwarm)

# %%
fig, axe = plt.subplots()
xcset = axe.contour(Z, Y, X, 30, cmap=cm.coolwarm)
